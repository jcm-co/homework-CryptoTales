# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jcmignon/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_news1 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language ="en",sort_by='relevancy',page = 1)['articles'])
btc_news2 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language ="en",sort_by='relevancy',page = 2)['articles'])
btc_news3 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language ="en",sort_by='relevancy',page = 3)['articles'])
btc_news4 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language ="en",sort_by='relevancy',page = 4)['articles'])
btc_news5 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language ="en",sort_by='relevancy',page = 5)['articles'])

btc_news = pd.concat([btc_news1,btc_news2,btc_news3,btc_news4,btc_news5])
btc_news
# Out:
#                                     source  \
# 0   {'id': 'engadget', 'name': 'Engadget'}
# 1      {'id': None, 'name': 'Gizmodo.com'}
# 2   {'id': 'mashable', 'name': 'Mashable'}
# 3   {'id': 'bbc-news', 'name': 'BBC News'}
# 4      {'id': None, 'name': 'Gizmodo.com'}
# ..                                     ...
# 15    {'id': 'reuters', 'name': 'Reuters'}
# 16    {'id': 'reuters', 'name': 'Reuters'}
# 17    {'id': 'reuters', 'name': 'Reuters'}
# 18    {'id': 'reuters', 'name': 'Reuters'}
# 19    {'id': 'reuters', 'name': 'Reuters'}
#
#                                                author  \
# 0   https://www.engadget.com/about/editors/saqib-shah
# 1                                          Matt Novak
# 2                                      Stan Schroeder
# 3                    https://www.facebook.com/bbcnews
# 4                                       Alyse Stanley
# ..                                                ...
# 15                                            Reuters
# 16                                         Tom Wilson
# 17                                      Reuters Staff
# 18                           Gertrude Chavez-dreyfuss
# 19                                            Reuters
#
#                                                 title  \
# 0   El Salvador becomes the first country to appro...
# 1   El Salvador Becomes First Country to Recognize...
# 2   Elon Musk says Tesla will resume Bitcoin purch...
# 3   Bitcoin: El Salvador makes cryptocurrency lega...
# 4   Miami's Bitcoin Conference May Be the Latest C...
# ..                                                ...
# 15  Square to invest $5 mln in Blockstream's solar...
# 16  EXCLUSIVE El Salvador bitcoin transfers soar, ...
# 17  IMF sees legal, economic issues with El Salvad...
# 18  Crypto sees 2nd week of outflows; ether posts ...
# 19  IMF sees legal, economic issues with El Salvad...
#
#                                           description  \
# 0   El Salvador has voted to adopt Bitcoin as lega...
# 1   El Salvador has become the first country in th...
# 2   It's all about clean energy, it seems. \nElon ...
# 3   It is the first country in the world to make t...
# 4   Several crypto fans that descended on Miami, F...
# ..                                                ...
# 15  Blockchain technology company Blockstream Mini...
# 16  Small transfers of bitcoin to El Salvador jump...
# 17  The International Monetary Fund said on Thursd...
# 18  Cryptocurrency investment products and funds s...
# 19  The International Monetary Fund said on Thursd...
#
#                                                   url  \
# 0   https://www.engadget.com/el-salvador-bitcoin-l...
# 1   https://gizmodo.com/el-salvador-becomes-first-...
# 2   https://mashable.com/article/tesla-bitcoin-pur...
# 3   https://www.bbc.co.uk/news/world-latin-america...
# 4   https://gizmodo.com/miamis-bitcoin-conference-...
# ..                                                ...
# 15  https://www.reuters.com/technology/square-inve...
# 16  https://www.reuters.com/business/finance/exclu...
# 17  https://www.reuters.com/article/us-el-salvador...
# 18  https://www.reuters.com/technology/crypto-sees...
# 19  https://www.reuters.com/business/finance/imf-s...
#
#                                            urlToImage           publishedAt  \
# 0   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-06-09T12:04:40Z
# 1   https://i.kinja-img.com/gawker-media/image/upl...  2021-06-09T10:00:00Z
# 2   https://mondrian.mashable.com/2021%252F06%252F...  2021-06-14T07:15:49Z
# 3   https://ichef.bbci.co.uk/news/1024/branded_new...  2021-06-09T08:27:58Z
# 4   https://i.kinja-img.com/gawker-media/image/upl...  2021-06-11T00:45:00Z
# ..                                                ...                   ...
# 15                                               None  2021-06-05T18:22:00Z
# 16  https://www.reuters.com/resizer/AUSGmfvZnVBr2N...  2021-06-14T14:24:00Z
# 17  https://static.reuters.com/resources/r/?m=02&d...  2021-06-10T14:30:00Z
# 18  https://www.reuters.com/resizer/tZ8a3w6k8k2N_N...  2021-06-14T21:26:00Z
# 19  https://www.reuters.com/resizer/eHbe0Fbrs00lAh...  2021-06-10T14:48:00Z
#
#                                               content
# 0   El Salvador's President Nayib Bukele has made ...
# 1   El Salvador has become the first country in th...
# 2   It's all about clean energy, it seems. \r\nElo...
# 3   image captionThe move means bitcoin will be ac...
# 4   Several crypto fans that descended on Miami, F...
# ..                                                ...
# 15  Blockchain technology company Blockstream Mini...
# 16  : Bitcoin banners are seen outside of a small ...
# 17  By Reuters Staff\r\nFILE PHOTO: The Internatio...
# 18  Cryptocurrency investment products and funds s...
# 19  The International Monetary Fund said on Thursd...
#
# [100 rows x 8 columns]

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy')

eth_news1 = pd.DataFrame(newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy',page = 1)['articles'])
eth_news2 = pd.DataFrame(newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy',page = 2)['articles'])
eth_news3 = pd.DataFrame(newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy',page = 3)['articles'])
eth_news4 = pd.DataFrame(newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy',page = 4)['articles'])
eth_news5 = pd.DataFrame(newsapi.get_everything(q="ethereum", language ="en",sort_by='relevancy',page = 5)['articles'])

eth_news = pd.concat([eth_news1,eth_news2,eth_news3,eth_news4,eth_news5])
eth_news.head()
# Out:
#                                               source  \
# 0             {'id': 'mashable', 'name': 'Mashable'}
# 1             {'id': 'mashable', 'name': 'Mashable'}
# 2               {'id': None, 'name': 'Entrepreneur'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4                {'id': None, 'name': 'Gizmodo.com'}
#
#                                    author  \
# 0                            Joseph Green
# 1                              Tim Marcin
# 2                 Entrepreneur en Español
# 3  cshumba@insider.com (Camomile Shumba )
# 4                         Whitney Kimball
#
#                                                title  \
# 0  This blockchain development course bundle is o...
# 1               Classic memes that have sold as NFTs
# 2  Ethereum creator Vitalik Buterin made more tha...
# 3  Ethereum now has more active addresses than bi...
# 4                                    8 Money Toilets
#
#                                          description  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  Ethereum billionaire founder Vitalik Buterin b...
# 3  Ethereum overtook bitcoin in the number of act...
# 4  A ferocious bidding war over a misshapen chick...
#
#                                                  url  \
# 0  https://mashable.com/uk/shopping/june-17-crypt...
# 1  https://mashable.com/article/classic-memes-sol...
# 2        https://www.entrepreneur.com/article/374264
# 3  https://markets.businessinsider.com/news/stock...
# 4     https://gizmodo.com/8-money-toilets-1847036893
#
#                                           urlToImage           publishedAt  \
# 0  https://mondrian.mashable.com/2021%252F06%252F...  2021-06-17T04:05:00Z
# 1  https://mondrian.mashable.com/2021%252F06%252F...  2021-06-20T19:28:07Z
# 2  https://assets.entrepreneur.com/content/3x2/20...  2021-06-10T19:12:00Z
# 3  https://images2.markets.businessinsider.com/60...  2021-07-02T15:49:56Z
# 4  https://i.kinja-img.com/gawker-media/image/upl...  2021-06-04T22:20:00Z
#
#                                              content
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  This article was translated from our Spanish e...
# 3  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...
# 4  CryptoPunks represent the only historically re...

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiment = []

for content in btc_news['content']:
    sentiment = analyzer.polarity_scores(content)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]
        
    btc_sentiment.append({
            "text": content,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu   
        })

# Create DataFrame
btc_df = pd.DataFrame(btc_sentiment)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral
# 0       0.0    0.718
# 1       0.0    0.957
# 2       0.0    0.831
# 3       0.0    0.940
# 4       0.0    0.893

# %%
# Create the Bitcoin sentiment scores DataFrame
eth_sentiment = []

for content in eth_news['content']:
    sentiment = analyzer.polarity_scores(content)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]
        
    eth_sentiment.append({
            "text": content,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu   
        })

# Create DataFrame
eth_df = pd.DataFrame(eth_sentiment)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...    0.0000     0.000
# 1  It wasn't long ago that your average person ha...   -0.2960     0.000
# 2  This article was translated from our Spanish e...   -0.3400     0.000
# 3  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612     0.110
# 4  CryptoPunks represent the only historically re...   -0.4588     0.067
#
#    negative  neutral
# 0     0.000    1.000
# 1     0.061    0.939
# 2     0.066    0.934
# 3     0.041    0.849
# 4     0.151    0.782

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.061507    0.047040    0.028200    0.924750
# std      0.352836    0.063612    0.043421    0.070162
# min     -0.778300    0.000000    0.000000    0.718000
# 25%     -0.081925    0.000000    0.000000    0.871000
# 50%      0.000000    0.000000    0.000000    0.929000
# 75%      0.323650    0.084000    0.060500    1.000000
# max      0.840200    0.282000    0.178000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          compound   positive    negative     neutral
# count  100.000000  100.00000  100.000000  100.000000
# mean     0.150449    0.05848    0.022150    0.919390
# std      0.362227    0.06918    0.036668    0.071027
# min     -0.571900    0.00000    0.000000    0.710000
# 25%      0.000000    0.00000    0.000000    0.875250
# 50%      0.051350    0.04600    0.000000    0.927000
# 75%      0.411525    0.09725    0.057750    1.000000
# max      0.848100    0.29000    0.151000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# *__A: Etheruem had the highest mean positive score, 5.49% vs 4.68% for Bitcoin.__*
#
# Q: Which coin had the highest compound score?
#
# *__A: Ethereum had the highest mean compound score (12.84% vs 5.92% respectively), as well as the highest compound score for an individual article (84.81% vs 84.02% respectively).__*
#
# Q. Which coin had the highest positive score?
#
# *__A: Ethereum had the highest positive score (29% vs 28.2% for ETH)__*

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import reuters, stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
btc_string=" ".join(btc_news['content'].astype(str))

# %%
# Create a list of stopwords
sentence = sent_tokenize(btc_string)
words = word_tokenize(btc_string)
sw = set(stopwords.words('english'))
first_result = [word.lower() for word in words if word.lower() not in sw]

# unsure if the list has to be expanded 
# Expand list with char reuters

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

    # Create a tokenized list of the words
    words = word_tokenize(re_clean)    
    
    # Define the stop words
    sw = stopwords.words('english')
    # Additional words as they appear in the top 10 most common words and add little to no value
    sw_addon = {'char', 'reuters'}
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    output = [word.lower() for word in lem if word.lower() not in sw]
    
    # unsure how to add the custom list - .union(sw_addon) - to be pasted behind sw. in the previous line, error: union is not recognized
    
    return output

# %%
# Create a new tokens column for Bitcoin
btc_token = btc_news['content'].apply(tokenizer)
btc_df['token'] = btc_token.values
btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral                                              token
# 0       0.0    0.718  [el, salvadors, president, nayib, bukele, ha, ...
# 1       0.0    0.957  [el, salvador, ha, become, first, country, wor...
# 2       0.0    0.831  [clean, energy, seemselon, musk, tesla, caused...
# 3       0.0    0.940  [image, captionthe, move, mean, bitcoin, accep...
# 4       0.0    0.893  [several, crypto, fan, descended, miami, flori...

# %%
# Create a new tokens column for Ethereum
eth_token = eth_news['content'].apply(tokenizer)
eth_df['token'] = eth_token.values
eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...    0.0000     0.000
# 1  It wasn't long ago that your average person ha...   -0.2960     0.000
# 2  This article was translated from our Spanish e...   -0.3400     0.000
# 3  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612     0.110
# 4  CryptoPunks represent the only historically re...   -0.4588     0.067
#
#    negative  neutral                                              token
# 0     0.000    1.000  [tldr, cryptocurrency, ethereum, solidity, blo...
# 1     0.061    0.939  [wasnt, long, ago, average, person, clue, nft,...
# 2     0.066    0.934  [article, wa, translated, spanish, edition, us...
# 3     0.041    0.849  [bitcoin, ethereumyuriko, nakaoether, overtook...
# 4     0.151    0.782  [cryptopunks, represent, historically, relevan...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Create btc_string of all tokenized words per article 
btc_string = " ".join(btc_df['token'].astype(str))
# Tokenize btc_string to ensure you have one big string 
btc_string_processed = tokenizer(btc_string)

# %%
# Generate the Bitcoin N-grams where N=2
btc_counts = Counter(ngrams(btc_string_processed, n=2))
print(dict(btc_counts))
# Out:
# {('el', 'salvador'): 21, ('salvador', 'president'): 2, ('president', 'nayib'): 7, ('nayib', 'bukele'): 6, ('bukele', 'ha'): 1, ('ha', 'made'): 1, ('made', 'good'): 1, ('good', 'promise'): 1, ('promise', 'adopt'): 1, ('adopt', 'bitcoin'): 3, ('bitcoin', 'legal'): 12, ('legal', 'tender'): 11, ('tender', 'official'): 1, ('official', 'central'): 1, ('central', 'american'): 3, ('american', 'country'): 1, ('country', 'congress'): 1, ('congress', 'voted'): 1, ('voted', 'accept'): 1, ('accept', 'cryptocurrency'): 1, ('cryptocurrency', 'majori'): 1, ('majori', 'char'): 1, ('char', 'el'): 5, ('salvador', 'ha'): 6, ('ha', 'become'): 6, ('become', 'first'): 5, ('first', 'country'): 6, ('country', 'world'): 6, ('world', 'recognize'): 1, ('recognize', 'cryptocurrency'): 1, ('cryptocurrency', 'bitcoin'): 4, ('legal', 'currency'): 1, ('currency', 'according'): 1, ('according', 'president'): 1, ('bukele', 'tweet'): 1, ('tweet', 'wednesday'): 1, ('wednesday', 'citizen'): 1, ('citizen', 'able'): 1, ('able', 'char'): 1, ('char', 'clean'): 1, ('clean', 'energy'): 2, ('energy', 'seemselon'): 1, ('seemselon', 'musk'): 1, ('musk', 'tesla'): 1, ('tesla', 'caused'): 1, ('caused', 'ripple'): 1, ('ripple', 'cryptocurrency'): 1, ('cryptocurrency', 'market'): 1, ('market', 'past'): 1, ('past', 'month'): 1, ('month', 'first'): 1, ('first', 'announcing'): 1, ('announcing', 'tesla'): 1, ('tesla', 'bought'): 1, ('bought', 'billion'): 1, ('billion', 'worth'): 1, ('worth', 'bitcoi'): 1, ('bitcoi', 'char'): 3, ('char', 'image'): 1, ('image', 'captionthe'): 1, ('captionthe', 'move'): 1, ('move', 'mean'): 1, ('mean', 'bitcoin'): 1, ('bitcoin', 'accepted'): 1, ('accepted', 'everywhere'): 1, ('everywhere', 'good'): 1, ('good', 'service'): 1, ('service', 'alongside'): 1, ('alongside', 'u'): 2, ('u', 'dollarel'): 1, ('dollarel', 'salvador'): 1, ('world', 'officially'): 1, ('officially', 'classify'): 1, ('classify', 'bitcoin'): 2, ('bitcoin', 'char'): 1, ('char', 'several'): 1, ('several', 'crypto'): 1, ('crypto', 'fan'): 1, ('fan', 'descended'): 1, ('descended', 'miami'): 1, ('miami', 'florida'): 1, ('florida', 'last'): 1, ('last', 'weekend'): 1, ('weekend', 'largest'): 1, ('largest', 'bitcoin'): 1, ('bitcoin', 'conference'): 1, ('conference', 'history'): 1, ('history', 'saying'): 1, ('saying', 'theyve'): 1, ('theyve', 'tested'): 1, ('tested', 'positive'): 1, ('positive', 'covid'): 1, ('covid', 'larry'): 1, ('larry', 'cermak'): 1, ('cermak', 'research'): 1, ('research', 'director'): 1, ('director', 'char'): 1, ('char', 'hello'): 2, ('hello', 'friend'): 1, ('friend', 'welcome'): 1, ('welcome', 'back'): 2, ('back', 'week'): 1, ('week', 'reviewlast'): 1, ('reviewlast', 'week'): 1, ('week', 'wrote'): 1, ('wrote', 'tech'): 1, ('tech', 'taking'): 1, ('taking', 'disney'): 1, ('disney', 'week'): 1, ('week', 'im'): 1, ('im', 'talking'): 1, ('talking', 'search'): 1, ('search', 'new'): 1, ('new', 'crypto'): 1, ('crypto', 'messiahif'): 1, ('messiahif', 'youre'): 1, ('youre', 'reading'): 1, ('reading', 'tec'): 1, ('tec', 'char'): 1, ('char', 'maryann'): 1, ('maryann', 'russonbusiness'): 1, ('russonbusiness', 'reporter'): 1, ('reporter', 'bbc'): 1, ('bbc', 'newsimage'): 1, ('newsimage', 'copyrightgetty'): 1, ('copyrightgetty', 'imagesformer'): 1, ('imagesformer', 'u'): 1, ('u', 'president'): 1, ('president', 'donald'): 1, ('donald', 'trump'): 1, ('trump', 'ha'): 1, ('ha', 'told'): 1, ('told', 'fox'): 1, ('fox', 'business'): 1, ('business', 'see'): 1, ('see', 'bitcoin'): 1, ('bitcoin', 'scam'): 1, ('scam', 'affecting'): 1, ('affecting', 'value'): 1, ('value', 'u'): 1, ('u', 'dolla'): 1, ('dolla', 'char'): 1, ('char', 'san'): 2, ('san', 'salvador'): 3, ('salvador', 'june'): 5, ('june', 'reuters'): 23, ('reuters', 'el'): 7, ('salvador', 'replace'): 2, ('replace', 'u'): 2, ('u', 'dollar'): 3, ('dollar', 'bitcoin'): 2, ('tender', 'finance'): 2, ('finance', 'minister'): 2, ('minister', 'alejandro'): 2, ('alejandro', 'zelaya'): 2, ('zelaya', 'said'): 2, ('said', 'wednesday'): 3, ('wednesda ...

# %%
# Generate the Ethereum N-grams where N=2
# Create eth_string of all tokenized words per article 
eth_string = " ".join(eth_df['token'].astype(str))
# Tokenize eth_string to ensure you have one big string 
eth_string_processed = tokenizer(eth_string)
# Generate the Ethereum N-grams where N=2
eth_counts = Counter(ngrams(eth_string_processed, n=2))
print(dict(eth_counts))
# Out:
# {('tldr', 'cryptocurrency'): 2, ('cryptocurrency', 'ethereum'): 4, ('ethereum', 'solidity'): 2, ('solidity', 'blockchain'): 2, ('blockchain', 'developer'): 2, ('developer', 'bundle'): 2, ('bundle', 'sale'): 1, ('sale', 'june'): 1, ('june', 'saving'): 1, ('saving', 'list'): 1, ('list', 'priceis'): 1, ('priceis', 'everyone'): 1, ('everyone', 'know'): 1, ('know', 'investing'): 1, ('investing', 'cryptocurrency'): 1, ('cryptocurrency', 'char'): 9, ('char', 'wasnt'): 1, ('wasnt', 'long'): 2, ('long', 'ago'): 2, ('ago', 'average'): 1, ('average', 'person'): 1, ('person', 'clue'): 1, ('clue', 'nft'): 1, ('nft', 'wa'): 1, ('wa', 'nowadays'): 1, ('nowadays', 'theyre'): 1, ('theyre', 'making'): 1, ('making', 'headline'): 1, ('headline', 'selling'): 1, ('selling', 'hundred'): 1, ('hundred', 'thousand'): 1, ('thousand', 'buck'): 1, ('buck', 'predictably'): 1, ('predictably', 'folk'): 1, ('folk', 'learning'): 1, ('learning', 'nfts'): 1, ('nfts', 'char'): 1, ('char', 'article'): 5, ('article', 'wa'): 5, ('wa', 'translated'): 5, ('translated', 'spanish'): 5, ('spanish', 'edition'): 5, ('edition', 'using'): 5, ('using', 'ai'): 5, ('ai', 'technology'): 5, ('technology', 'error'): 5, ('error', 'may'): 5, ('may', 'exist'): 5, ('exist', 'due'): 5, ('due', 'processlast'): 1, ('processlast', 'may'): 1, ('may', 'vitalik'): 1, ('vitalik', 'buterin'): 1, ('buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', 'ye'): 1, ('ye', 'char'): 1, ('char', 'bitcoin'): 6, ('bitcoin', 'ethereumyuriko'): 1, ('ethereumyuriko', 'nakaoether'): 1, ('nakaoether', 'overtook'): 1, ('overtook', 'bitcoin'): 1, ('bitcoin', 'number'): 1, ('number', 'active'): 1, ('active', 'address'): 1, ('address', 'network'): 1, ('network', 'friday'): 1, ('friday', 'sign'): 1, ('sign', 'demand'): 1, ('demand', 'faltering'): 1, ('faltering', 'world'): 1, ('world', 'biggest'): 13, ('biggest', 'cryptocurrency'): 1, ('cryptocurrency', 'co'): 1, ('co', 'char'): 1, ('char', 'cryptopunks'): 1, ('cryptopunks', 'represent'): 1, ('represent', 'historically'): 1, ('historically', 'relevant'): 1, ('relevant', 'narrative'): 1, ('narrative', 'upon'): 1, ('upon', 'value'): 1, ('value', 'could'): 1, ('could', 'conceivably'): 1, ('conceivably', 'live'): 1, ('live', 'decade'): 1, ('decade', 'within'): 1, ('within', 'expanding'): 1, ('expanding', 'catalogue'): 1, ('catalogue', 'raisonn'): 1, ('raisonn', 'ill'): 1, ('ill', 'damned'): 1, ('damned', 'im'): 1, ('im', 'counting'): 1, ('counting', 'jack'): 1, ('jack', 'tweet'): 1, ('tweet', 'char'): 2, ('char', 'major'): 1, ('major', 'upgrade'): 1, ('upgrade', 'ethereum'): 1, ('ethereum', 'network'): 1, ('network', 'could'): 1, ('could', 'help'): 1, ('help', 'turn'): 1, ('turn', 'crypto'): 1, ('crypto', 'staking'): 1, ('staking', 'billion'): 1, ('billion', 'business'): 1, ('business', 'according'): 1, ('according', 'analyst'): 1, ('analyst', 'jpmorganthe'): 1, ('jpmorganthe', 'staking'): 1, ('staking', 'industry'): 1, ('industry', 'user'): 1, ('user', 'earn'): 1, ('earn', 'cryptocurrency'): 1, ('char', 'sir'): 1, ('sir', 'tim'): 1, ('tim', 'bernerslee'): 5, ('bernerslee', 'credited'): 1, ('credited', 'inventor'): 1, ('inventor', 'world'): 1, ('world', 'wide'): 7, ('wide', 'web'): 7, ('web', 'selling'): 1, ('selling', 'source'): 1, ('source', 'code'): 3, ('code', 'invention'): 1, ('invention', 'nft'): 1, ('nft', 'sothebys'): 1, ('sothebys', 'auctionthe'): 1, ('auctionthe', 'nft'): 1, ('nft', 'nonfungible'): 1, ('nonfungible', 'token'): 8, ('token', 'type'): 1, ('type', 'cryp'): 1, ('cryp', 'char'): 2, ('char', 'two'): 1, ('two', 'ethereumbased'): 1, ('ethereumbased', 'protocol'): 1, ('protocol', 'keep'): 1, ('keep', 'network'): 1, ('network', 'nucypher'): 1, ('nucypher', 'getting'): 1, ('getting', 'upgradesinto'): 1, ('upgradesinto', 'single'): 1, ('single', 'network'): 1, ('network', 'last'): 1, ('last', 'week'): 2, ('week', 'token'): 1, ('token', 'holder'): 1, ('holder', 'project'): 1, ('project', ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin

# Create string with individual words
btc_counts_indiv = Counter(ngrams(btc_string_processed, n=1))
# Apply token_count function
token_count(btc_counts_indiv)

#Alternative solution
# print(dict(btc_counts_indiv.most_common(10)))
# Out:
# [(('char',), 97),
#  (('bitcoin',), 96),
#  (('reuters',), 57),
#  (('june',), 38),
#  (('cryptocurrency',), 31),
#  (('salvador',), 28),
#  (('el',), 26),
#  (('world',), 24),
#  (('monday',), 19),
#  (('seen',), 19)]

# %%
# Use token_count to get the top 10 words for Ethereum

# Create string with individual words
eth_counts_indiv = Counter(ngrams(eth_string_processed, n=1))
# Apply token_count function
token_count(eth_counts_indiv)

#Alternative solution
# print(dict(eth_counts_indiv.most_common(10)))
# Out:
# [(('char',), 99),
#  (('bitcoin',), 41),
#  (('reuters',), 34),
#  (('cryptocurrency',), 33),
#  (('world',), 26),
#  (('june',), 23),
#  (('ethereum',), 14),
#  (('biggest',), 14),
#  (('representation',), 14),
#  (('week',), 13)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud

# confused - btc_string_processed is already a string (error given - expects a string like object)

wc = WordCloud().generate(btc_string_processed)
plt.imshow(wc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-7f47dbc3f318> in <module>
#       3 #btc_text = process_text(big_string)
#       4
# ----> 5 wc = WordCloud().generate(btc_string_processed)
#       6 plt.imshow(wc)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/wordcloud/wordcloud.py in process_text(self, text)
#     573         regexp = self.regexp if self.regexp is not None else pattern
#     574
# --> 575         words = re.findall(regexp, text, flags)
#     576         # remove 's
#     577         words = [word[:-2] if word.lower().endswith("'s") else word
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Generate the Ethereum word cloud

wc = WordCloud().generate(eth_string_processed)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
#already done in btc_string

# %%
# Run the NER processor on all of the text
btc_NER = nlp(btc_string)

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
displacy.render(btc_NER, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ['el'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 'salvadors', 'president', 'nayib', 'bukele', 'ha', 'made', 'good', 'promise', 'adopt', 'bitcoin', 'legal', 'tender', 'officials', 'central', '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     american
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ', 'country', 'congress', 'voted', 'accept', 'cryptocurrency', 'majori', 'char'] ['el', 'salvador', 'ha', 'become', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ', 'country', 'world', 'recognize', 'cryptocurrency', 'bitcoin', 'legal', 'currency', 'according', 'president', 'nayib', 'bukele', 'tweet', 'wednesday', 'citizens', 'able', 'char'] ['clean', 'energy', 'seemselon', 'musk', 'tesla', 'caused', 'ripple', 'cryptocurrency', 'market', 'past',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'month'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ', 'announcing', 'tesla', 'bought', 'billion', 'worth', 'bitcoi', 'char'] ['image', 'captionthe', 'move', 'mean', 'bitcoin', 'accepted', 'everywhere', 'good', 'service', 'alongside', 'us', 'dollarel', 'salvador', 'ha', 'become', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ', 'country', 'world', 'officially', 'classify', 'bitcoin', 'char'] ['several', 'crypto', 'fan', 'descended', 'miami', '
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ', 'last', 'weekend', 'largest', 'bitcoin', 'conference', 'history', 'saying', 'theyve', 'tested', 'positive', 'covid', 'larry', 'cermak', 'research', 'director', 'char'] ['hello', 'friend', 'welcome', 'back', 'week', 'reviewlast',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'week'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 'wrote', 'tech', 'taking', 'disney',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'week'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 'im', 'talking', 'search', 'new', 'crypto', 'messiahif', 'youre', 'reading', 'tec', 'char'] ['
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maryann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ', 'russonbusiness', 'reporter', 'bbc', 'newsimage', 'copyrightgetty', 'imagesformer', 'us', 'president', 'donald', 'trump', 'ha', 'told', 'fox', 'business', 'see', 'bitcoin', 'scam', 'affecting', 'value', 'us', 'dolla', 'char'] ['san', 'salvador', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     june
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'reuters', 'el', 'salvador', 'replace', 'us', 'dollar', 'bitcoin', 'legal', 'tender', 'finance', 'minister', 'alejandro', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zelaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ', 'said', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'central', '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     american
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ', 'nation', 'char'] ['london', 'june', 'reuters', 'el', 'salvador', 'determined', 'push', 'ahead', 'making', 'bitcoin', 'legal', 'tender', 'process', 'bring', 'small', 'risk', 'prove', 'leap', 'forward', 'humanity', 'country', 'pr', 'char'] ['london', 'june', 'reuters', 'el', 'salvador', 'determined', 'push', 'ahead', 'making', 'bitcoin', 'legal', 'tender', 'process', 'bring', 'small', 'risk', 'prove', 'leap', 'forward', 'humanity', 'country', 'char'] ['representations', 'virtual', 'currency', 'bitcoin', 'stand', 'motherboard', 'picture', 'illustration', 'taken', 'may', 'reutersdado', 'ruvicillustrationfile', 'photomicrostrategy', 'inc', 'mstro', 'major', 'b', 'char'] ['reuters', 'staffsan', 'salvador', 'reuters', 'el', 'salvador', 'replace', 'us', 'dollar', 'bitcoin', 'legal', 'tender', 'finance', 'minister', 'alejandro', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zelaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ', 'said', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'central', '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height

# %%
# List all Entities
# all geopolitical entities like in the example. Not sure if that's the question
print([ent.text for ent in btc_NER.ents if ent.label_ == 'GPE'])
# Out:
# ['florida', 'china', 'germany', 'china', "'york'", 'china', 'china', 'paris', "'salvador'", "'york'", "'york'", 'london', "'york'", "'york'", 'china', 'america', "'york'", 'london', 'china', "'beach'", 'washington', "'york'"]

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# already done in eth_string

# %%
# Run the NER processor on all of the text
eth_NER = nlp(eth_string)

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
displacy.render(eth_NER, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">['tldr', 'cryptocurrency', 'ethereum', 'solidity', 'blockchain', 'developer', 'bundle', 'sale', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     june
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'saving', 'list', 'priceis', 'everyone', 'know', 'investing', 'cryptocurrency', 'char'] ['wasnt', 'long', 'ago', 'average', 'person', 'clue', 'nft', 'wa', 'nowadays', 'theyre', 'making', 'headline', 'selling', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundred
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ', 'thousand', 'buck', 'predictably', 'folk', 'learning', 'nfts', 'char'] ['article', 'wa', 'translated', '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ', 'edition', 'using', 'ai', 'technology', 'errors', 'may', 'exist', 'due', 'processlast', 'may', 'vitalik', 'buterin', 'became', 'youngest', 'billionaire', 'world', 'ye', 'char'] ['bitcoin', 'ethereumyuriko', 'nakaoether', 'overtook', 'bitcoin', 'number', 'active', 'address', 'network', 'friday', 'sign', 'demand', 'faltering', 'world', 'biggest', 'cryptocurrency', 'co', 'char'] ['cryptopunks', 'represent', 'historically', 'relevant', 'narrative', 'upon', 'value', 'could', 'conceivably', 'live', 'decade', 'within', 'expanding', 'catalogue', 'raisonn', 'ill', 'damned', 'im', 'counting', 'jacks', 'tweet', 'char'] ['major', 'upgrade', 'ethereum', 'network', 'could', 'help', 'turn', 'crypto', 'staking', 'billion', 'business', 'according', 'analyst', 'jpmorganthe', 'staking', 'industry', 'user', 'earn', 'cryptocurrency', 'char'] ['sir', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tim'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , 'bernerslee', 'credited', 'inventor', 'world', 'wide', 'web', 'selling', 'source', 'code', 'invention', 'nft', 'sothebys', 'auctionthe', 'nft', 'nonfungible', 'token', 'type', 'cryp', 'char'] ['
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ', 'ethereumbased', 'protocol', 'keep', 'network', 'nucypher', 'getting', 'upgradesinto', 'single', 'network', 'last', 'week', 'token', 'holder', 'project', 'voted'] ['youve', 'likely', 'seen', 'headline', 'surrounding', 'pretty', 'major', 'decline', 'nft', 'sale', 'market', 'recent', 'peak', 'report', 'indicating', 'much', 'percent', 'decline', 'recent', 'week', 'whi', 'char'] ['ambition', 'crypto', 'investor', 'swelled', 'even', 'faster', 'market', 'ha', 'recent',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'month'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 'institutional', 'player', 'mountain', 'blockchain', 'data', 'try', 'make', 'sense', 'without', 'par', 'char'] ['bitcoin', 'surged', 'wednesday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'year'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 'low', 'jan', 'char'] ['bitcoin', 'dropped', 'gmt', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'high', 'char'] ['tldr', 'cryptocurrency', 'ethereum', 'solidity', 'blockchain', 'developer', 'bundle', 'explains', 'entire', 'crypto', 'phenomenon', 'also', 'explores', 'creating', 'real', 'world', 'cryptocurrencyif', 'knowledge', 'char'] ['ina', 'fassbenderafp', 'via', 'getty', 'imagesinvestors', 'pulled', 'money', 'digital', 'asset', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ', 'week', 'running', 'making', 'longest', 'series', 'consecutive', 'outflow', 'since', 'february', 'coinsh', 'char'] ['bitcoin', 'surged', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency',
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'year'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 'low', 'char'] ['reuters', 'staffjune', 'reuters', 'bitcoin', 'dipped', 'gmt', '
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'] ['
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'staffjune', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'bitcoin', 'rose', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'] ['
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'staffjune', '
# <mark class="entity" style="background: #7aecec;

# %%
# List all Entities
# all geopolitical entities like in the example. Not sure if that's the question
print([ent.text for ent in eth_NER.ents if ent.label_ == 'GPE'])
# Out:
# ["'york'", 'china', 'london', 'britain', 'london', 'london', 'staffmumbai', "'york'", 'london', 'london', 'shanghai', 'china', 'beijing', 'india']

# %% [markdown]
# ---
